# %%
import numpy as np
import pandas as pd

# %%
# Creating series

subjects = ["Maths", "Biology", "Physics", "Chemistry"]
marks = [86, 91, 75, 83]
print(pd.Series(marks, index= subjects, name= "Result"))
# Out:
# Maths        86
# Biology      91
# Physics      75
# Chemistry    83
# Name: Result, dtype: int64

# %%
sub= pd.Series(marks, index= subjects, name= "Result")
sub.size
# Out:
# 4

# %%
type(sub)
# Out:
# pandas.core.series.Series

# %%
data = pd.read_csv(r'C:\Users\ibad\Desktop\Pandas\Pandas\kohli_ipl.csv', index_col='match_no')
data = data.squeeze()
type(data)
# Out:
# pandas.core.series.Series

# %%
print("sorting data", data.sort_values())
# Arranging in desending 
print("A",data.sort_values(ascending=False).head(1)) # This will give both column
print("B",data.sort_values(ascending=False).head(1).values) # This will give list with a value
print("C",data.sort_values(ascending=False).head(1).values[0]) # Give singal value
# Out:
# sorting data match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64
# A match_no
# 128    113
# Name: runs, dtype: int64
# B [113]
# C 113
